# %%
# Convert binary to base64

import base64

with open('ODU Well.xlsx', 'rb') as file:
    binary_data = file.read()
    base64_data = base64.b64encode(binary_data).decode('utf-8')

print(base64_data)
# Out:
# ...
